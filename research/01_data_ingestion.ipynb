# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Projects\\DL-Projects\\Chicken disease\\Chicken-fecal-images\\Chicken-fecal-images\\Chicken-Disease-Classification-Project\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Projects\\DL-Projects\\Chicken disease\\Chicken-fecal-images\\Chicken-fecal-images\\Chicken-Disease-Classification-Project'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir:Path
    source_URL:str
    local_data_file: Path
    unzip_dir: Path

# %%
from CNNClassifier.constants import *
from CNNClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
            self,
            config_filepath = CONFIG_FILE_PATH,
            params_filepath = PARAMS_FILE_PATH):
        
            self.config = read_yaml(config_filepath)
            self.params = read_yaml(params_filepath)

            create_directories([self.config.artifacts_root])



    def get_data_ingestion_config(self) -> DataIngestionConfig:
          config = self.config.data_ingestion

          create_directories([config.root_dir])

          data_ingestion_config = DataIngestionConfig(
                root_dir=config.root_dir,
                source_URL=config.source_URL,
                local_data_file=config.local_data_file,
                unzip_dir=config.unzip_dir
          )        
          return data_ingestion_config

# %%
import os
import urllib.request as request
import zipfile
import ssl
import certifi
from CNNClassifier import logger
from CNNClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config


    def download_file(self):
        if not os.path.exists(self.config.local_data_file):
            
            filename, headers = request.urlretrieve(
                url = self.config.source_URL,
                filename = self.config.local_data_file
            )    
            logger.info(f"{filename} download! with following info: \n{headers}")
        else:
            logger.info(f"File already exists of size: {get_size(Path(self.config.local_data_file))}")    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-08-13 11:57:47,793: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-08-13 11:57:47,798: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-08-13 11:57:47,800: INFO: common: created directory at: artifacts]
# [2026-08-13 11:57:47,803: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-08-13 11:57:47,804: INFO: 1905116083: File already exists of size: ~ 10887 KB]
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[12], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[12], line 6
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#       5     data_ingestion.download_file()
# ----> 6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
#       8     raise e
#
# ...

# %%
from pathlib import Path

config = ConfigurationManager()
data_ingestion_config = config.get_data_ingestion_config()

print("URL:")
print(data_ingestion_config.source_URL)

print("\nLocal file:")
print(data_ingestion_config.local_data_file)

print("\nUnzip directory:")
print(data_ingestion_config.unzip_dir)

file_path = Path(data_ingestion_config.local_data_file)

print("\nExists:", file_path.exists())

if file_path.exists():
    print("Size:", file_path.stat().st_size, "bytes")
    print("Size:", round(file_path.stat().st_size / (1024 * 1024), 2), "MB")

    with open(file_path, "rb") as f:
        print("First 20 bytes:", f.read(20))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 from pathlib import Path
# ----> 3 config = ConfigurationManager()
#       4 data_ingestion_config = config.get_data_ingestion_config()
#       6 print("URL:")
#
# Cell In[17], line 7, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       2 def __init__(
#       3         self,
#       4         config_filepath = CONFIG_FILE_PATH,
#       5         params_filepath = PARAMS_FILE_PATH):
# ----> 7         self.config = read_yaml(config_filepath)
#       8         self.params = read_yaml(params_filepath)
#      10         create_directories([self.config.artifacts_root])
#
# File c:\Users\HRIDYA RAMESH K\.conda\envs\chicken\lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
# ...

# %%
import urllib.request
import zipfile
import os

url = "https://github.com/Hridya04/Trial/raw/refs/heads/main/Chicken-fecal-images.zip"

test_file = "test_dataset.zip"

urllib.request.urlretrieve(url, test_file)

print("Downloaded size:", os.path.getsize(test_file), "bytes")
print("Is genuine ZIP:", zipfile.is_zipfile(test_file))

with open(test_file, "rb") as f:
    print("First 4 bytes:", f.read(4))
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# Cell In[13], line 9
#       5 url = "https://github.com/Hridya04/Trial/raw/refs/heads/main/Chicken-fecal-images.zip"
#       7 test_file = "test_dataset.zip"
# ----> 9 urllib.request.urlretrieve(url, test_file)
#      11 print("Downloaded size:", os.path.getsize(test_file), "bytes")
#      12 print("Is genuine ZIP:", zipfile.is_zipfile(test_file))
#
# File c:\Users\HRIDYA RAMESH K\.conda\envs\chicken\lib\urllib\request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
# ...

# %%
import zipfile

zip_path = r"C:\Projects\DL-Projects\Chicken disease\Chicken-fecal-images\Chicken-fecal-images.zip"

print("Is genuine ZIP:", zipfile.is_zipfile(zip_path))

with open(zip_path, "rb") as f:
    print("First 4 bytes:", f.read(4))
# Out:
# Is genuine ZIP: True
# First 4 bytes: b'PK\x03\x04'

# %%
import zipfile

zip_path = r"C:\Users\HRIDYA RAMESH K\Downloads\Chicken-fecal-images.zip"

print("Is genuine ZIP:", zipfile.is_zipfile(zip_path))

with open(zip_path, "rb") as f:
    print("First 4 bytes:", f.read(4))
# Out:
# Is genuine ZIP: True
# First 4 bytes: b'PK\x03\x04'

# %%
def extract_zip_file(self):
    unzip_path = self.config.unzip_dir
    os.makedirs(unzip_path, exist_ok=True)

    with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
        zip_ref.extractall(unzip_path)

# %%
config = ConfigurationManager()

data_ingestion_config = config.get_data_ingestion_config()

data_ingestion = DataIngestion(
    config=data_ingestion_config
)

data_ingestion.download_file()
data_ingestion.extract_zip_file()
# Out:
# [2026-08-13 12:02:37,895: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-08-13 12:02:37,899: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-08-13 12:02:37,902: INFO: common: created directory at: artifacts]
# [2026-08-13 12:02:37,904: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-08-13 12:02:37,906: INFO: 1905116083: File already exists of size: ~ 10887 KB]
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[16], line 10
#       5 data_ingestion = DataIngestion(
#       6     config=data_ingestion_config
#       7 )
#       9 data_ingestion.download_file()
# ---> 10 data_ingestion.extract_zip_file()
#
# Cell In[11], line 25, in DataIngestion.extract_zip_file(self)
#      23 unzip_path = self.config.unzip_dir
#      24 os.makedirs(unzip_path, exist_ok=True)
# ...
